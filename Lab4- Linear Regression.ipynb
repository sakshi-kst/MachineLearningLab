# %% [markdown]
# Sakshi Kulshreshtha: 16BCE1198

# %% [markdown]
# Boston Housing Dataset

# %%
import pandas as pd

# %%
df=pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data",sep="\s+")

# %%
df.columns=['crim','zn','indus','chas','nox','rm','age','dis','rad','tax','ptratio','b','lstat','medv']

# %%
df
# Out:
#          crim    zn  indus  chas    nox     rm    age     dis  rad    tax  \
# 0     0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242.0
# 1     0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242.0
# 2     0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222.0
# 3     0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222.0
# 4     0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222.0
# 5     0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311.0
# 6     0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311.0
# 7     0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311.0
# 8     0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311.0
# 9     0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311.0
# 10    0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267    5  311.0
# 11    0.09378  12.5   7.87     0  0.524  5.889   39.0  5.4509    5  311.0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style='whitegrid',context='notebook')

# %%
cols=['lstat','indus','nox','rm','medv']

# %%
sns.pairplot(df[cols],size=2.5)

# %%
plt.tight_layout()
plt.show()

# %%
import numpy as np

# %%
cm=np.corrcoef(df[cols].values.T)

# %%
sns.set(font_scale=1.5)

# %%
hm=sns.heatmap(cm,cbar=True,annot=True,square=True,fmt='.2f',annot_kws={'size':15},xticklabels=cols,yticklabels=cols)

# %%
plt.show()

# %%
X=df[['rm']].values
y=df['medv'].values

# %%
from sklearn.linear_model import LinearRegression

# %%
slr=LinearRegression()

# %%
slr.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print('Slope: %.3f' % slr.coef_[0])
print('Intercept: %.3f' % slr.intercept_)
# Out:
# Slope: 9.103
# Intercept: -34.677

# %%
def lin_regplot(X, y, model):
    plt.scatter(X, y, c='blue')
    plt.plot(X, model.predict(X), color='red', linewidth=2)
    return

# %%
lin_regplot(X,y,slr)
plt.xlabel('Average number of rooms [RM]')
plt.ylabel('Price in $1000\'s [MEDV]')
plt.tight_layout()
plt.show()

# %%
from sklearn.cross_validation import train_test_split
X=df.iloc[:,:-1].values
y=df['medv'].values
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)

# %%
slr=LinearRegression()
slr.fit(X_train,y_train)
y_train_pred=slr.predict(X_train)
y_test_pred=slr.predict(X_test)

# %%
plt.scatter(y_train_pred,y_train_pred-y_train,c='blue',marker='o',label='Training data')
plt.scatter(y_test_pred,y_test_pred-y_test,c='yellow',marker='s',label='Test data')
plt.xlabel('Predicted values')
plt.ylabel('Residuals')
plt.legend(loc='upper left')
plt.hlines(y=0,xmin=-10,xmax=50,lw=2,color='red')
plt.title('Scatterplot')
plt.show()

# %% [markdown]
# OULAD Dataset

# %%
df=pd.read_csv("E:/SEM 5/MACHINE LEARNING/LAB/Dataset-OULAD/StudentInfoPreprocessed.csv")

# %%
df
# Out:
#       code_module code_presentation  id_student gender                region  \
# 0             AAA             2013J       11391      M   East Anglian Region
# 1             AAA             2013J       28400      F              Scotland
# 2             AAA             2013J       30268      F  North Western Region
# 3             AAA             2013J       31604      F     South East Region
# 4             AAA             2013J       32885      F  West Midlands Region
# 5             AAA             2013J       38053      M                 Wales
# 6             AAA             2013J       45462      M              Scotland
# 7             AAA             2013J       45642      F  North Western Region
# 8             AAA             2013J       52130      F   East Anglian Region
# 9             AAA             2013J       53025      M          North Region
# 10            AAA             2013J       57506      M          South Region
# ...

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
df.iloc[:,3] = labelencoder.fit_transform(df.iloc[:,3])
df.iloc[:,4] = labelencoder.fit_transform(df.iloc[:,4])
df.iloc[:,5] = labelencoder.fit_transform(df.iloc[:,5])
df.iloc[:,6] = labelencoder.fit_transform(df.iloc[:,6])
df.iloc[:,7] = labelencoder.fit_transform(df.iloc[:,7])
df.iloc[:,10] = labelencoder.fit_transform(df.iloc[:,10])
df.iloc[:,11] = labelencoder.fit_transform(df.iloc[:,11])

# %%
df
# Out:
#       code_module code_presentation  id_student  gender  region  \
# 0             AAA             2013J       11391       1       0
# 1             AAA             2013J       28400       0       6
# 2             AAA             2013J       30268       0       5
# 3             AAA             2013J       31604       0       7
# 4             AAA             2013J       32885       0      11
# 5             AAA             2013J       38053       1      10
# 6             AAA             2013J       45462       1       6
# 7             AAA             2013J       45642       0       5
# 8             AAA             2013J       52130       0       0
# 9             AAA             2013J       53025       1       4
# 10            AAA             2013J       57506       1       8
# 11            AAA             2013J       58873       0       0
# 12            AAA             2013J       59185       1       0
# 13            AAA             2013J       62155       0       5
# ...

# %%
labelencoder_name_mapping = dict(zip(labelencoder.classes_, labelencoder.transform(labelencoder.classes_)))
print(labelencoder_name_mapping)
# Out:
# {'Distinction': 0, 'Fail': 1, 'Pass': 2, 'Withdrawn': 3}

# %%
list(labelencoder.inverse_transform([1,0,2,3]))
# Out:
# ['Fail', 'Distinction', 'Pass', 'Withdrawn']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style='whitegrid',context='notebook')

# %%
cols=['gender','region','highest_education','imd_band','age_band','num_of_prev_attempts','studied_credits','disability','final_result']

# %%
sns.pairplot(df[cols],size=2.5)

# %%
plt.tight_layout()
plt.show()

# %%
import numpy as np

# %%
cm=np.corrcoef(df[cols].values.T)

# %%
sns.set(font_scale=1.5)

# %%
hm=sns.heatmap(cm,cbar=True,annot=True,square=True,fmt='.2f',annot_kws={'size':10},xticklabels=cols,yticklabels=cols)

# %%
plt.show()

# %%
X=df[['studied_credits']].values
y=df['final_result'].values

# %%
from sklearn.linear_model import LinearRegression

# %%
slr=LinearRegression()

# %%
slr.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print('Slope: %.3f' % slr.coef_[0])
print('Intercept: %.3f' % slr.intercept_)
# Out:
# Slope: 0.004
# Intercept: 1.630

# %%
def lin_regplot(X, y, model):
    plt.scatter(X, y, c='blue')
    plt.plot(X, model.predict(X), color='red', linewidth=2)
    return

# %%
lin_regplot(X,y,slr)
plt.xlabel('Studied Credits')
plt.ylabel('Final Result')
plt.tight_layout()
plt.show()

# %%
from sklearn.cross_validation import train_test_split
X=df.iloc[:,3:-1].values
y=df['final_result'].values
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)

# %%
slr=LinearRegression()
slr.fit(X_train,y_train)
y_train_pred=slr.predict(X_train)
y_test_pred=slr.predict(X_test)

# %%
plt.scatter(y_train_pred,y_train_pred-y_train,c='blue',marker='.',label='Training data')
plt.scatter(y_test_pred,y_test_pred-y_test,c='lightgreen',marker='x',label='Test data',alpha=0.3)
plt.xlabel('Predicted values')
plt.ylabel('Residuals')
plt.legend(loc='upper left')
plt.hlines(y=0,xmin=1,xmax=4,lw=2,color='red')
plt.title('Scatterplot')
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score

# %%
X=df[['studied_credits']].values
y=df['final_result'].values

# %%
# create polynomial features
quadratic=PolynomialFeatures(degree=2)
cubic=PolynomialFeatures(degree=3)
X_quad=quadratic.fit_transform(X)
X_cubic=cubic.fit_transform(X)

# %%
# linear fit
X_fit=np.arange(X.min(),X.max(),1)[:,np.newaxis]
slr=slr.fit(X,y)
y_lin_fit=slr.predict(X_fit)
linear_r2=r2_score(y,slr.predict(X))

# %%
# quadratic fit
slr=slr.fit(X_quad,y)
y_quad_fit=slr.predict(quadratic.fit_transform(X_fit))
quadratic_r2=r2_score(y,slr.predict(X_quad))

# %%
# cubic fit
slr=slr.fit(X_cubic,y)
y_cubic_fit=slr.predict(cubic.fit_transform(X_fit))
cubic_r2=r2_score(y,slr.predict(X_cubic))

# %%
plt.scatter(X,y,label='training points',color='lightgray')
plt.plot(X_fit,y_lin_fit,label='linear (d=1), $R^2=%.2f$' %linear_r2,color='blue',lw=2,linestyle=':')
plt.plot(X_fit,y_quad_fit,label='quadratic (d=2), $R^2=%.2f$' %quadratic_r2,color='red',lw=2,linestyle='-')
plt.plot(X_fit,y_cubic_fit,label='cubic (d=3), $R^2=%.2f$' %cubic_r2,color='green',lw=2,linestyle='--')
plt.xlabel('Studied Credits')
plt.ylabel('Final Result')
plt.legend(loc='upper right',prop={'size':10})
plt.show()
